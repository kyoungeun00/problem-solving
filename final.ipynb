# %% [markdown]
# # 1. LeetCode 225.Implement Stack using Queues

# %%
from collections import deque

class MyStack:

    def __init__(self):
        self.queue = deque()  # 한 개의 큐 사용

    def push(self, x: int) -> None:
        self.queue.append(x)  # 새 요소를 큐에 추가
        # 새로 추가한 요소를 앞쪽으로 이동시키기 위해 큐를 재구성
        for _ in range(len(self.queue) - 1):
            self.queue.append(self.queue.popleft())

    def pop(self) -> int:
        # 큐의 맨 앞이 스택의 top이므로 이를 제거
        return self.queue.popleft()

    def top(self) -> int:
        # 큐의 맨 앞 요소 반환
        return self.queue[0]

    def empty(self) -> bool:
        # 큐가 비어 있는지 확인
        return not self.queue
# Out:
# 2
# 2
# False

# %% [markdown]
# # 2. LeetCode 232. Implement Queue using Stacks

# %%
MyQueue:

    def __init__(self):
        self.input_stack = []  # 데이터를 추가하는 스택
        self.output_stack = []  # 데이터를 제거하거나 반환하는 스택

    def push(self, x: int) -> None:
        self.input_stacclassk.append(x)  # 입력 스택에 요소 추가

    def pop(self) -> int:
        self._transfer()  # 출력 스택이 비어 있으면 데이터 이동
        return self.output_stack.pop()

    def peek(self) -> int:
        self._transfer()  # 출력 스택이 비어 있으면 데이터 이동
        return self.output_stack[-1]

    def empty(self) -> bool:
        return not self.input_stack and not self.output_stack

    def _transfer(self):
        """입력 스택에서 출력 스택으로 데이터를 옮깁니다."""
        if not self.output_stack:  # 출력 스택이 비어 있을 때만 이동
            while self.input_stack:
                self.output_stack.append(self.input_stack.pop())

# %% [markdown]
# # 3. chapter7

# %%
1.
class ListQueue:
    def __init__(self):
        self.__queue = []

    def enqueue(self, x):  # 큐에 데이터 추가 (리스트 앞쪽에 삽입)
        self.__queue.insert(0, x)

    def dequeue(self):  # 큐에서 데이터 제거 (리스트 끝쪽에서 제거)
        return self.__queue.pop()

    def front(self):  # 큐의 front 값 반환 (리스트 끝쪽 값)
        return self.__queue[-1]

    def isEmpty(self) -> bool:  # 큐가 비었는지 확인
        return len(self.__queue) == 0

    def dequeueAll(self):  # 큐 비우기
        self.__queue.clear()

2.
class Queue:
    def __init__(self):
        self.__queue = []

    def enqueue(self, x):
        self.__queue.append(x)

    def dequeue(self):
        if not self.isEmpty():
            return self.__queue.pop(0)
        return None

    def isEmpty(self):
        return len(self.__queue) == 0

def check_string(input_string):
    queue = Queue()
    for char in input_string:
        queue.enqueue(char)

    # 문자열에 '$'가 하나만 있는지 확인
    if input_string.count('$') != 1:
        return False

    # '$' 기준으로 나누기
    parts = input_string.split('$')
    if len(parts) != 2:
        return False

    # 앞부분과 뒷부분이 같은지 확인
    w1, w2 = parts
    return w1 == w2

# 테스트
input_string = "abc$abc"
print(check_string(input_string))  # 출력: True

3.
class LinkedQueue:
    def __init__(self):
        self.queue = []

    def enqueue(self, x):
        self.queue.append(x)

    def dequeue(self):
        if not self.isEmpty():
            return self.queue.pop(0)
        return None

    def isEmpty(self):
        return len(self.queue) == 0

    def copy_to(self, other_queue):
        for item in self.queue:
            other_queue.enqueue(item)

# 테스트
queue_a = LinkedQueue()
queue_a.enqueue(1)
queue_a.enqueue(2)
queue_a.enqueue(3)

queue_b = LinkedQueue()
queue_a.copy_to(queue_b)

print(queue_b.queue)  # 출력: [1, 2, 3]

4.
class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, x):
        self.queue.append(x)

    def dequeue(self):
        if not self.isEmpty():
            return self.queue.pop(0)
        return None

    def isEmpty(self):
        return len(self.queue) == 0

class StackUsingTwoQueues:
    def __init__(self):
        self.queue1 = Queue()
        self.queue2 = Queue()

    def push(self, x):
        self.queue1.enqueue(x)

    def pop(self):
        if self.queue1.isEmpty():
            return None

        # 마지막 요소를 제외하고 모두 queue2로 이동
        while len(self.queue1.queue) > 1:
            self.queue2.enqueue(self.queue1.dequeue())

        # 마지막 요소가 스택의 top
        top_element = self.queue1.dequeue()

        # 큐 교환
        self.queue1, self.queue2 = self.queue2, self.queue1

        return top_element

# 테스트
stack = StackUsingTwoQueues()
stack.push(1)
stack.push(2)
stack.push(3)

print(stack.pop())  # 출력: 3

5.
class Stack:
    def __init__(self):
        self.stack = []

    def push(self, x):
        self.stack.append(x)

    def pop(self):
        if not self.isEmpty():
            return self.stack.pop()
        return None

    def isEmpty(self):
        return len(self.stack) == 0

class QueueUsingTwoStacks:
    def __init__(self):
        self.stack1 = Stack()
        self.stack2 = Stack()

    def enqueue(self, x):
        self.stack1.push(x)

    def dequeue(self):
        if self.stack2.isEmpty():
            while not self.stack1.isEmpty():
                self.stack2.push(self.stack1.pop())

        return self.stack2.pop()

# 테스트
queue = QueueUsingTwoStacks()
queue.enqueue(1)
queue.enqueue(2)
queue.enqueue(3)

print(queue.dequeue())  # 출력: 1

6.
import time

class ListQueue:
    def __init__(self):
        self.__queue = []

    def enqueue(self, x):
        self.__queue.append(x)

    def dequeue(self):
        return self.__queue.pop(0)

# 수행 시간 측정 함수
def measure_times(n):
    queue = ListQueue()

    # enqueue 시간 측정
    start_time = time.time()
    for i in range(n):
        queue.enqueue(i)
    enqueue_time = time.time() - start_time

    # dequeue 시간 측정
    start_time = time.time()
    for i in range(n):
        queue.dequeue()
    dequeue_time = time.time() - start_time

    return enqueue_time, dequeue_time

# 테스트 (큐 크기 n=1000)
n = 1000
enqueue_time, dequeue_time = measure_times(n)
print(f"Enqueue 시간: {enqueue_time}, Dequeue 시간: {dequeue_time}")

7.
import time

class LinkedListBasic:
    class Node:
        def __init__(self, data):
            self.data = data
            self.next = None

    def __init__(self):
        self.head = None
        self.tail = None

    def enqueue(self, x):
        new_node = LinkedListBasic.Node(x)
        if self.tail:
            self.tail.next = new_node
        self.tail = new_node
        if not self.head:
            self.head = new_node

    def dequeue(self):
        if not self.head:
            return None

        data = self.head.data
        self.head = self.head.next

        if not self.head:
            self.tail = None

        return data

# 수행 시간 측정 함수
def measure_times_linked_list(n):
    queue = LinkedListBasic()

    # enqueue 시간 측정
    start_time = time.time()
    for i in range(n):
        queue.enqueue(i)
    enqueue_time = time.time() - start_time

    # dequeue 시간 측정
    start_time = time.time()
    for i in range(n):
        queue.dequeue()
    dequeue_time = time.time() - start_time

    return enqueue_time, dequeue_time

# 테스트 (큐 크기 n=1000)
n = 1000
enqueue_time, dequeue_time = measure_times_linked_list(n)
print(f"Enqueue 시간: {enqueue_time}, Dequeue 시간: {dequeue_time}")

8.
class ListDeque:
    def __init__(self):
        self.__deque = []

    # 앞쪽에 데이터 삽입
    def addFront(self, x):
        self.__deque.insert(0, x)

    # 뒤쪽에 데이터 삽입
    def addRear(self, x):
        self.__deque.append(x)

    # 앞쪽에서 데이터 제거
    def removeFront(self):
        if not self.isEmpty():
            return self.__deque.pop(0)
        return None

    # 뒤쪽에서 데이터 제거
    def removeRear(self):
        if not self.isEmpty():
            return self.__deque.pop()
        return None

    # 앞쪽 데이터 반환
    def getFront(self):
        if self.isEmpty():
            return None
        return self.__deque[0]

    # 뒤쪽 데이터 반환
    def getRear(self):
        if self.isEmpty():
            return None
        return self.__deque[-1]

    # Deque 비어있는지 확인
    def isEmpty(self) -> bool:
        return len(self.__deque) == 0

    # Deque 전체 비우기
    def clear(self):
        self.__deque.clear()

    # Deque 출력
    def printDeque(self):
        print("Deque from front:", end=" ")
        for item in self.__deque:
            print(item, end=" ")
        print()
